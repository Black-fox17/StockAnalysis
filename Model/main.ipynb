# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.51-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\python312\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\python312\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\python312\lib\site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in c:\python312\lib\site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\owner\appdata\roaming\python\python312\site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in c:\python312\lib\site-packages (from yfinance) (2024.1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py312-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.8.tar.gz (948 kB)
#      ---------------------------------------- 0.0/948.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/948.2 kB ? eta -:--:--
#      ----------- ---------------------------- 262.1/948.2 kB ? eta -:--:--
#      --------------------- ---------------- 524.3/948.2 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 948.2/948.2 kB 1.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\python312\lib\site-packages (from yfinance) (4.12.3)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\python312\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Collecting webencodings (from html5lib>=1.1->yfinance)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python312\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests>=2.31->yfinance) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Downloading yfinance-0.2.51-py2.py3-none-any.whl (104 kB)
# Downloading frozendict-2.4.6-py312-none-any.whl (16 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.8-py3-none-any.whl size=139014 sha256=c5ba17f12f80f12ba85d143cf309d0fa1b33ff49743864788537ac4b7e6e3626
#   Stored in directory: c:\users\owner\appdata\local\pip\cache\wheels\8f\65\34\456800445efeafb05164fe95285c70e81ba1d96bae30f43917
# Successfully built peewee
# Installing collected packages: webencodings, peewee, multitasking, html5lib, frozendict, yfinance
# WARNING: Ignoring invalid distribution ~angchain (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angsmith (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angsmith (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: 'C:\\Python312\\Scripts\\pwiz.py'
# Consider using the `--user` option or check the permissions.

# %%
import yfinance as yf
import pandas as pd
import numpy as np

# Define the stock ticker and the period for which you want the data
ticker = 'AAPL'
period = '10y'

# Download the stock data
stock_data = yf.download(ticker, period=period)

# Create a DataFrame with the specified columns
df = pd.DataFrame(stock_data)
df.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-01-02  243.850006  249.100006  241.820007  248.929993  55740700
# 2025-01-03  243.360001  244.179993  241.889999  243.360001  40244100
# 2025-01-06  245.000000  247.330002  243.199997  244.309998  45045600
# 2025-01-07  242.210007  245.550003  241.350006  242.979996  40856000
# 2025-01-08  242.699997  243.710007  240.050003  241.919998  37564700

# %%
df.shape
# Out:
# (2516, 5)

# %%
data =  df.filter([( 'Close', 'AAPL')])
dataset = data.values
training_data_len = int(np.ceil( len(dataset) * .95 ))
testing_data_len = data.shape[0] - training_data_len

# %%
dataset
# Out:
# array([[9.88344923e-02],
#        [9.36782211e-02],
#        [8.68024528e-02],
#        ...,
#        [2.43360001e+02],
#        [2.45000000e+02],
#        [2.42210007e+02]])

# %%
dataset.shape
# Out:
# (11109, 1)

# %%
np.array([[8],[3],[4],[6]]).shape
# Out:
# (4, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaler.fit(dataset)
# Out:
# MinMaxScaler()

# %%
import joblib

joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
scaled_data = scaler.transform(dataset)

# %%
v = scaled_data[0:60,0]
v.shape
# Out:
# (60,)

# %%
scaled_data
# Out:
# array([[0.0178192 ],
#        [0.01524025],
#        [0.01614664],
#        ...,
#        [0.94117225],
#        [0.92946547],
#        [0.93152146]])

# %%
# Create the training data set 
# Create the scaled training data set
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# x_train.shape
# Out:
# [array([0.0178192 , 0.01524025, 0.01614664, 0.01575416, 0.01296957,
#        0.012194  , 0.01474496, 0.01552054, 0.01818368, 0.01872564,
#        0.01883775, 0.01513745, 0.02090284, 0.0242574 , 0.02263153,
#        0.02400513, 0.02402382, 0.0248741 , 0.02567154, 0.02472405,
#        0.02546516, 0.02762281, 0.03030578, 0.031788  , 0.03236963,
#        0.03307321, 0.03390818, 0.03365484, 0.03463988, 0.03792328,
#        0.03714461, 0.03397379, 0.03550292, 0.03366424, 0.03425521,
#        0.03450853, 0.03373928, 0.03174111, 0.03191935, 0.03242596,
#        0.0299587 , 0.02782917, 0.02990239, 0.02909563, 0.03037148,
#        0.03233212, 0.03367363, 0.03276366, 0.03126266, 0.03249161,
#        0.03200379, 0.02889863, 0.0297054 , 0.0287767 , 0.0317036 ,
#        0.02988366, 0.0297148 , 0.03071857, 0.03262293, 0.03136587])]
# [0.03098123969760802]
#
# [array([0.0178192 , 0.01524025, 0.01614664, 0.01575416, 0.01296957,
#        0.012194  , 0.01474496, 0.01552054, 0.01818368, 0.01872564,
#        0.01883775, 0.01513745, 0.02090284, 0.0242574 , 0.02263153,
#        0.02400513, 0.02402382, 0.0248741 , 0.02567154, 0.02472405,
#        0.02546516, 0.02762281, 0.03030578, 0.031788  , 0.03236963,
#        0.03307321, 0.03390818, 0.03365484, 0.03463988, 0.03792328,
#        0.03714461, 0.03397379, 0.03550292, 0.03366424, 0.03425521,
#        0.03450853, 0.03373928, 0.03174111, 0.03191935, 0.03242596,
#        0.0299587 , 0.02782917, 0.02990239, 0.02909563, 0.03037148,
#        0.03233212, 0.03367363, 0.03276366, 0.03126266, 0.03249161,
#        0.03200379, 0.02889863, 0.0297054 , 0.0287767 , 0.0317036 ,
#        0.02988366, 0.0297148 , 0.03071857, 0.03262293, 0.03136587]), array([0.01524025, 0.01614664, 0.01575416, 0.01296957, 0.012194  ,
#        0.01474496, 0.01552054, 0.01818368, 0.01872564, 0.01883775,
#        0.01513745, 0.02090284, 0.0242574 , 0.02263153, 0.02400513,
#        0.02402382, 0.0248741 , 0.02567154, 0.02472405, 0.02546516,
#        0.02762281, 0.03030578, 0.031788  , 0.03236963, 0.03307321,
#        0.03390818, 0.03365484, 0.03463988, 0.03792328, 0.03714461,
#        0.03397379, 0.03550292, 0.03366424, 0.03425521, 0.03450853,
#        0.03373928, 0.03174111, 0.03191935, 0.03242596, 0.0299587 ,
#        0.02782917, 0.02990239, 0.02909563, 0.03037148, 0.03233212,
#        0.03367363, 0.03276366, 0.03126266, 0.03249161, 0.03200379,
#        0.02889863, 0.0297054 , 0.0287767 , 0.0317036 , 0.02988366,
#        0.0297148 , 0.03071857, 0.03262293, 0.03136587, 0.03098124])]
# [0.03098123969760802, 0.03188181776601465]

# %%
x_train.shape
# Out:
# (2331, 60, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2331/2331 ━━━━━━━━━━━━━━━━━━━━ 72s 29ms/step - loss: 0.0037

# %%
test_data = scaled_data[training_data_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    
# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step
# 4.07374548168244

# %%
test_data.shape
# Out:
# (185, 1)

# %%
y_test
# Out:
# array([[254.49000549],
#        [255.27000427],
#        [258.20001221],
#        [259.01998901],
#        [255.58999634],
#        [252.19999695],
#        [250.41999817],
#        [243.8500061 ],
#        [243.36000061],
#        [245.        ],
#        [242.21000671],
#        [243.33999634]])

# %%
x_test = []
for i in range(60,len(test_data)):
    x_test.append(test_data[i - 60:i,0])

# %%
len(x_test)
# Out:
# 12

# %%
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step

# %%
dataset[training_data_len:] == y_test
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True]])

# %%
predictions
# Out:
# array([[136.92921 ],
#        [138.12955 ],
#        [139.76106 ],
#        [141.75423 ],
#        [142.04863 ],
#        [140.50317 ],
#        [142.82074 ],
#        [144.14995 ],
#        [143.98637 ],
#        [141.87282 ],
#        [138.37405 ],
#        [136.05688 ],
#        [135.15724 ],
#        [135.10094 ],
#        [133.66377 ],
#        [136.2881  ],
#        [139.27429 ],
#        [140.48795 ],
#        [141.34035 ],
#        [141.35214 ],
#        [141.9149  ],
#        [142.6526  ],
#        [142.19664 ],
#        [142.5031  ],
#        [143.13718 ],
#        [142.64044 ],
#        [140.91577 ],
#        [138.72353 ],
#        [139.5854  ],
#        [140.7404  ],
#        [141.29341 ],
#        [141.05354 ],
#        [139.50653 ],
#        [137.71135 ],
#        [137.18852 ],
#        [137.00055 ],
#        [137.71834 ],
#        [138.56706 ],
#        [138.28107 ],
#        [135.6832  ],
#        [133.07083 ],
#        [130.86784 ],
#        [129.68456 ],
#        [130.20573 ],
#        [129.71431 ],
#        [128.98523 ],
#        [127.7628  ],
#        [125.557976],
#        [125.18571 ],
#        [125.39942 ],
#        [124.05135 ],
#        [123.33044 ],
#        [122.51132 ],
#        [123.440125],
#        [124.421425],
#        [125.13976 ],
#        [126.34854 ],
#        [127.091606],
#        [127.88573 ],
#        [128.77527 ],
#        [129.13574 ],
#        [129.33386 ],
#        [130.31886 ],
#        [132.13615 ],
#        [133.84312 ],
#        [134.62398 ],
#        [135.6084  ],
#        [136.89532 ],
#        [136.83742 ],
#        [137.06886 ],
#        [137.70427 ],
#        [139.95505 ],
#        [142.77005 ],
#        [143.63211 ],
#        [144.7293  ],
#        [144.56456 ],
#        [144.01486 ],
#        [143.86841 ],
#        [144.88551 ],
#        [145.55238 ],
#        [146.5834  ],
#        [146.70302 ],
#        [146.22906 ],
#        [144.55931 ],
#        [143.56567 ],
#        [143.32382 ],
#        [142.50432 ],
#        [142.30988 ],
#        [142.08669 ],
#        [141.21332 ],
#        [140.71658 ],
#        [142.08652 ],
#        [144.0768  ],
#        [144.59822 ],
#        [145.01492 ],
#        [144.49304 ],
#        [143.40036 ],
#        [143.36423 ],
#        [144.27946 ],
#        [145.14932 ],
#        [146.54904 ],
#        [147.13484 ],
#        [148.06773 ],
#        [149.26097 ],
#        [149.57722 ],
#        [150.02632 ],
#        [150.79587 ],
#        [150.74089 ],
#        [150.42679 ],
#        [151.2296  ],
#        [152.4187  ],
#        [153.99643 ],
#        [155.36932 ],
#        [155.9534  ],
#        [155.58684 ],
#        [155.55554 ],
#        [154.84508 ],
#        [154.02751 ],
#        [153.37846 ],
#        [154.7921  ],
#        [155.82588 ],
#        [156.32303 ],
#        [156.84538 ],
#        [157.48459 ],
#        [157.5799  ],
#        [157.08017 ],
#        [156.85078 ],
#        [156.32788 ],
#        [156.01886 ],
#        [157.35645 ],
#        [158.78223 ],
#        [159.55516 ],
#        [159.51733 ],
#        [159.00705 ],
#        [158.15005 ],
#        [160.12419 ],
#        [161.7553  ],
#        [162.1233  ],
#        [162.66397 ],
#        [163.04262 ],
#        [162.96867 ],
#        [162.75233 ],
#        [162.6717  ],
#        [162.90282 ],
#        [163.8628  ],
#        [164.56792 ],
#        [164.61462 ],
#        [163.68906 ],
#        [163.09738 ],
#        [163.20897 ],
#        [164.20096 ],
#        [165.51433 ],
#        [166.27997 ],
#        [167.47903 ],
#        [168.47215 ],
#        [168.59375 ],
#        [168.45638 ],
#        [167.97295 ],
#        [168.58612 ],
#        [169.29437 ],
#        [170.63062 ],
#        [171.32758 ],
#        [171.80641 ],
#        [172.67636 ],
#        [172.9195  ],
#        [173.04382 ],
#        [172.82649 ],
#        [173.65508 ],
#        [174.22952 ],
#        [174.10733 ],
#        [174.79695 ],
#        [175.68176 ],
#        [176.3359  ],
#        [178.03857 ],
#        [178.705   ],
#        [178.60701 ],
#        [178.61346 ],
#        [178.34169 ],
#        [177.58049 ],
#        [176.97089 ],
#        [177.20853 ],
#        [177.72244 ],
#        [178.08452 ],
#        [179.24202 ],
#        [179.89128 ],
#        [180.58656 ],
#        [180.37762 ],
#        [179.79309 ],
#        [179.70647 ],
#        [180.06117 ],
#        [180.6435  ],
#        [180.61986 ],
#        [181.30269 ],
#        [181.95981 ],
#        [182.067   ],
#        [181.12108 ],
#        [180.02094 ],
#        [176.58824 ],
#        [173.36682 ],
#        [171.88986 ],
#        [170.83258 ],
#        [170.16669 ],
#        [169.7191  ],
#        [169.84476 ],
#        [169.22144 ],
#        [168.36505 ],
#        [166.97272 ],
#        [166.23312 ],
#        [166.33891 ],
#        [166.96072 ],
#        [168.56793 ],
#        [168.07953 ],
#        [168.1031  ],
#        [168.64873 ],
#        [170.29828 ],
#        [172.54587 ],
#        [174.00452 ],
#        [175.21094 ],
#        [175.94305 ],
#        [174.23724 ],
#        [171.32639 ],
#        [169.78557 ],
#        [169.61519 ],
#        [168.85004 ],
#        [167.63362 ],
#        [167.2331  ],
#        [166.78789 ],
#        [167.36594 ],
#        [168.13016 ],
#        [167.43045 ],
#        [166.27798 ],
#        [165.80228 ],
#        [166.06221 ],
#        [165.05533 ],
#        [163.78906 ],
#        [163.06859 ],
#        [162.88284 ],
#        [163.63422 ],
#        [163.74399 ],
#        [164.04462 ],
#        [164.58244 ],
#        [165.7128  ],
#        [166.91798 ],
#        [167.43918 ],
#        [168.08766 ],
#        [168.79225 ],
#        [168.6729  ],
#        [168.49104 ],
#        [167.9384  ],
#        [167.20963 ],
#        [166.68573 ],
#        [165.63211 ],
#        [164.98428 ],
#        [164.79399 ],
#        [163.99315 ],
#        [162.07065 ],
#        [161.15695 ],
#        [161.41327 ],
#        [161.87595 ],
#        [163.1275  ],
#        [165.01993 ],
#        [165.84059 ],
#        [166.9035  ],
#        [168.35428 ],
#        [169.63078 ],
#        [170.25783 ],
#        [171.91342 ],
#        [172.58652 ],
#        [173.71626 ],
#        [174.65654 ],
#        [175.75288 ],
#        [176.44798 ],
#        [177.38689 ],
#        [177.76108 ],
#        [178.15858 ],
#        [178.02806 ],
#        [177.8787  ],
#        [178.02963 ],
#        [177.8837  ],
#        [177.96219 ],
#        [178.44504 ],
#        [178.21796 ],
#        [179.21214 ],
#        [179.60445 ],
#        [180.34541 ],
#        [181.25475 ],
#        [181.02592 ],
#        [181.22304 ],
#        [182.42784 ],
#        [183.346   ],
#        [183.68617 ],
#        [183.28712 ],
#        [183.29787 ],
#        [182.7541  ],
#        [182.37315 ],
#        [181.88431 ],
#        [181.44606 ],
#        [181.23573 ],
#        [181.26582 ],
#        [180.96628 ],
#        [178.59071 ],
#        [176.47935 ],
#        [174.5868  ],
#        [173.33725 ],
#        [174.07231 ],
#        [174.59096 ],
#        [175.06174 ],
#        [174.99065 ],
#        [174.87228 ],
#        [174.04974 ],
#        [173.20087 ],
#        [174.60818 ],
#        [176.69269 ],
#        [178.69069 ],
#        [180.1438  ],
#        [180.6199  ],
#        [180.64516 ],
#        [180.1234  ],
#        [179.65497 ],
#        [178.37895 ],
#        [176.49983 ],
#        [176.14384 ],
#        [175.85808 ],
#        [176.24023 ],
#        [176.9767  ],
#        [177.39584 ],
#        [177.17818 ],
#        [177.16277 ],
#        [176.66336 ],
#        [175.68982 ],
#        [174.82373 ],
#        [174.2836  ],
#        [173.55058 ],
#        [172.8491  ],
#        [172.64713 ],
#        [173.19905 ],
#        [173.0017  ],
#        [172.303   ],
#        [172.24554 ],
#        [171.92201 ],
#        [171.49425 ],
#        [170.8901  ],
#        [169.08627 ],
#        [166.29816 ],
#        [164.21829 ],
#        [163.09332 ],
#        [163.12173 ],
#        [163.87785 ],
#        [164.4472  ],
#        [163.93756 ],
#        [163.95053 ],
#        [163.87306 ],
#        [164.17778 ],
#        [165.1846  ],
#        [166.70593 ],
#        [165.36139 ],
#        [164.41501 ],
#        [163.4854  ],
#        [162.65323 ],
#        [163.37215 ],
#        [163.4642  ],
#        [162.93169 ],
#        [162.08542 ],
#        [161.75885 ],
#        [161.3778  ],
#        [161.39247 ],
#        [161.09967 ],
#        [161.25056 ],
#        [160.78183 ],
#        [162.68144 ],
#        [164.59274 ],
#        [164.4554  ],
#        [162.9831  ],
#        [161.49887 ],
#        [160.41383 ],
#        [159.30188 ],
#        [158.97496 ],
#        [159.23447 ],
#        [160.08284 ],
#        [160.84117 ],
#        [160.98343 ],
#        [162.23553 ],
#        [162.12198 ],
#        [161.55144 ],
#        [162.36995 ],
#        [166.3797  ],
#        [168.66966 ],
#        [169.91306 ],
#        [170.52768 ],
#        [171.39317 ],
#        [171.63962 ],
#        [172.84128 ],
#        [174.15321 ],
#        [175.71931 ],
#        [176.71956 ],
#        [177.2304  ],
#        [177.837   ],
#        [178.65878 ],
#        [178.78479 ],
#        [177.58301 ],
#        [177.73003 ],
#        [178.07361 ],
#        [178.43782 ],
#        [178.95418 ],
#        [179.5428  ],
#        [180.41595 ],
#        [181.04077 ],
#        [181.83606 ],
#        [181.90205 ],
#        [182.6156  ],
#        [181.98944 ],
#        [185.82059 ],
#        [190.44038 ],
#        [193.48947 ],
#        [194.38684 ],
#        [195.85625 ],
#        [196.13304 ],
#        [194.92563 ],
#        [193.58296 ],
#        [193.19339 ],
#        [193.52408 ],
#        [195.12527 ],
#        [196.40419 ],
#        [195.93332 ],
#        [197.21338 ],
#        [199.20747 ],
#        [200.8434  ],
#        [203.17868 ],
#        [205.0279  ],
#        [206.27965 ],
#        [208.22081 ],
#        [207.83784 ],
#        [208.32193 ],
#        [209.94989 ],
#        [211.23422 ],
#        [210.20695 ],
#        [207.98718 ],
#        [206.69073 ],
#        [206.07664 ],
#        [206.22052 ],
#        [204.47377 ],
#        [202.8971  ],
#        [202.10901 ],
#        [201.81825 ],
#        [201.8473  ],
#        [202.82864 ],
#        [202.30557 ],
#        [202.20227 ],
#        [198.96248 ],
#        [196.12672 ],
#        [195.40913 ],
#        [196.42012 ],
#        [198.09366 ],
#        [199.45932 ],
#        [201.13664 ],
#        [202.10606 ],
#        [203.4028  ],
#        [204.58722 ],
#        [205.26529 ],
#        [205.85596 ],
#        [206.22585 ],
#        [205.91904 ],
#        [206.41316 ],
#        [206.93639 ],
#        [207.52246 ],
#        [207.40665 ],
#        [208.24664 ],
#        [208.60484 ],
#        [206.90862 ],
#        [205.15314 ],
#        [204.66975 ],
#        [204.16396 ],
#        [203.93579 ],
#        [203.56735 ],
#        [204.04549 ],
#        [204.38052 ],
#        [204.41014 ],
#        [202.48923 ],
#        [201.30072 ],
#        [201.93571 ],
#        [205.03253 ],
#        [206.83958 ],
#        [207.06934 ],
#        [207.1589  ],
#        [206.87416 ],
#        [207.08907 ],
#        [207.4581  ],
#        [209.32799 ],
#        [208.5607  ],
#        [207.97598 ],
#        [207.32164 ],
#        [207.32536 ],
#        [205.92506 ],
#        [206.2219  ],
#        [207.73022 ],
#        [208.55592 ],
#        [208.42204 ],
#        [209.27724 ],
#        [210.60968 ],
#        [210.81064 ],
#        [210.91692 ],
#        [211.84055 ],
#        [212.93803 ],
#        [213.41759 ],
#        [212.11174 ],
#        [211.13689 ],
#        [210.93771 ],
#        [211.58932 ],
#        [212.16795 ],
#        [211.40042 ],
#        [209.5204  ],
#        [207.42183 ],
#        [205.98676 ],
#        [205.75394 ],
#        [205.57573 ],
#        [206.85872 ],
#        [207.56339 ],
#        [206.95033 ],
#        [206.34787 ],
#        [206.2579  ],
#        [207.24342 ],
#        [207.00621 ],
#        [207.638   ],
#        [208.15309 ],
#        [208.62814 ],
#        [208.72476 ],
#        [209.13338 ],
#        [210.30885 ],
#        [211.72935 ],
#        [212.5157  ],
#        [213.58075 ],
#        [214.87253 ],
#        [216.53964 ],
#        [217.63542 ],
#        [218.21336 ],
#        [218.45454 ],
#        [219.76253 ],
#        [220.97392 ],
#        [221.30925 ],
#        [221.84944 ],
#        [222.24619 ],
#        [223.3415  ],
#        [224.76643 ],
#        [224.02777 ],
#        [223.90663 ],
#        [225.3084  ],
#        [226.5294  ],
#        [228.0463  ],
#        [229.11644 ],
#        [228.6412  ],
#        [227.24553 ],
#        [225.93243 ],
#        [223.43237 ],
#        [221.90515 ],
#        [221.73201 ]], dtype=float32)

# %%
data["predictions"] = 0

# %%
data
# Out:
#                  Close predictions
#                   AAPL
# Date
# 2015-01-09   24.943985           0
# 2015-01-12   24.329361           0
# 2015-01-13   24.545374           0
# 2015-01-14   24.451838           0
# 2015-01-15   23.788208           0
# ...                ...         ...
# 2025-01-02  243.850006           0
# 2025-01-03  243.360001           0
# 2025-01-06  245.000000           0
# 2025-01-07  242.210007           0
# 2025-01-08  242.699997           0
#
# [2516 rows x 2 columns]

# %%
data.iloc[training_data_len:, data.columns.get_loc("predictions")] = predictions.flatten()
# Out:
# C:\Users\owner\AppData\Local\Temp\ipykernel_8044\826917985.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[228.8319  229.49033 230.49226 231.51965 231.24591 229.54335 227.50272
#  225.60944 224.38387 222.54742 220.66182 219.21864 218.34671 218.06528
#  218.77356 219.14677 219.60585 218.00768 215.36871 213.14253 212.15417
#  212.52492 213.82332 216.0634  218.41801 220.93533 223.24988 224.94608
#  226.08554 226.65912 226.45514 226.33243 226.30428 226.50063 226.48827
#  227.02805 227.57056 226.85863 225.34914 224.01065 222.7066  221.7265
#  220.96762 220.97478 221.38559 221.89432 221.20207 220.16727 219.84805
#  221.4532  223.56305 225.24171 226.55212 227.19002 227.56282 227.74303
#  228.76775 228.6816  228.23953 227.45996 226.88216 225.5458  224.91682
#  225.43991 226.35384 227.04787 228.22774 229.86748 231.01099 231.77097
#  232.70627 233.78894 234.60359 234.15303 233.15434 232.20638 231.83769
#  231.88493 231.47995 230.1811  228.14883 225.98476 224.44812 223.39124
#  223.71681 224.61449 225.15054 225.4251  225.65718 226.38266 226.56984
#  227.04942 227.58295 228.17339 228.57338 229.05325 230.02878 231.45581
#  232.79782 234.30011 235.99153 238.01279 239.8427  241.2185  242.04237
#  243.17003 244.375   245.13509 245.82762 246.36198 247.28398 248.67148
#  248.95195 249.03848 249.88844 251.06284 252.76595 254.54085 255.32841
#  254.83597 253.4659  250.6419  247.62775 245.42484 243.533  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.iloc[training_data_len:, data.columns.get_loc("predictions")] = predictions.flatten()

# %%
data.columns = ["Close","predictions"]

# %%
data
# Out:
#                  Close  predictions
# Date
# 2015-01-09   24.943985     0.000000
# 2015-01-12   24.329361     0.000000
# 2015-01-13   24.545374     0.000000
# 2015-01-14   24.451838     0.000000
# 2015-01-15   23.788208     0.000000
# ...                ...          ...
# 2025-01-02  243.850006   253.465897
# 2025-01-03  243.360001   250.641907
# 2025-01-06  245.000000   247.627747
# 2025-01-07  242.210007   245.424835
# 2025-01-08  242.699997   243.533005
#
# [2516 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,6))
plt.title("Model")
plt.xlabel("Date")
plt.ylabel("Price")
plt.plot(data["Close"].iloc[:training_data_len])
plt.plot(data["Close"].iloc[training_data_len:])
plt.plot(data["predictions"].iloc[training_data_len:])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()

# %%
model.save("apple.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("apple.keras")

# %%
from keras.models import load_model

test_model = load_model(r"C:\Users\owner\Desktop\2025\stock-prediction\api\Model\apple.keras")
# Out:
# c:\Python312\Lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 12 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
from extract import get_data
from sklearn.preprocessing import MinMaxScaler
import numpy as np

scaler = MinMaxScaler(feature_range=(0,1))
data = get_data("aapl",61)
data_values = np.array([[x["price"]] for x in data])
scaled_data = scaler.fit_transform(data_values)
test_data = scaled_data[-61:-1,0]

# %%
test_data
# Out:
# array([0.56187919, 0.54872483, 0.62362416, 0.57959732, 0.59275168,
#        0.76912752, 0.81691275, 0.90791946, 1.        , 0.97798658,
#        0.89932886, 0.87838926, 0.75221477, 0.70550336, 0.85127517,
#        0.78577181, 0.70765101, 0.70308725, 0.66362416, 0.69798658,
#        0.67060403, 0.56563758, 0.57100671, 0.57020134, 0.56053691,
#        0.47838926, 0.41771812, 0.35328859, 0.35677852, 0.29798658,
#        0.21744966, 0.18120805, 0.19409396, 0.1747651 , 0.16778523,
#        0.08671141, 0.17315436, 0.08993289, 0.06604027, 0.06604027,
#        0.13932886, 0.14657718, 0.0190604 , 0.03838926, 0.        ,
#        0.02416107, 0.10442953, 0.21691275, 0.31248322, 0.3052349 ,
#        0.25208054, 0.2295302 , 0.23463087, 0.37127517, 0.38791946,
#        0.34818792, 0.27194631, 0.26201342, 0.31731544])

# %%
pred = test_model.predict(x_test)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step

# %%
pred = scaler.inverse_transform(pred)

# %%
pred == predictions
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True]])

# %%
data
# Out:
#                  Close  predictions
# Date
# 1980-12-12    0.098834     0.000000
# 1980-12-15    0.093678     0.000000
# 1980-12-16    0.086802     0.000000
# 1980-12-17    0.088951     0.000000
# 1980-12-18    0.091530     0.000000
# ...                ...          ...
# 2024-12-31  250.419998   227.245529
# 2025-01-02  243.850006   225.932434
# 2025-01-03  243.360001   223.432373
# 2025-01-06  245.000000   221.905151
# 2025-01-07  242.210007   221.732010
#
# [11109 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11109 entries, 1980-12-12 to 2025-01-07
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   11109 non-null  float64
#  1   (High, AAPL)    11109 non-null  float64
#  2   (Low, AAPL)     11109 non-null  float64
#  3   (Open, AAPL)    11109 non-null  float64
#  4   (Volume, AAPL)  11109 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 520.7 KB

# %%
new_data = df.filter([("Close","AAPL")])

# %%
new_data.columns = ["close"]

# %%
dataset
# Out:
# array([[9.88344923e-02],
#        [9.36782211e-02],
#        [8.68024528e-02],
#        ...,
#        [2.43360001e+02],
#        [2.45000000e+02],
#        [2.42210007e+02]])

# %%
data_values = new_data.values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(data_values)

# %%
test_data = scaled_data[training_data_len:]
x_test = []

for i in range(60,len(test_data)):
    x_test.append(test_data[i - 60:i,0])

# %%
data_array = test_data[-61:-1,0]

# %%
x_test[-1]
# Out:
# array([0.88326724, 0.87752029, 0.89198414, 0.90181955, 0.89383547,
#        0.89526259, 0.9062551 , 0.91196351, 0.9095722 , 0.88990132,
#        0.88916855, 0.89240841, 0.90008387, 0.90112526, 0.8873557 ,
#        0.87119476, 0.85962368, 0.85615233, 0.86170644, 0.85889085,
#        0.87725026, 0.87620776, 0.86566646, 0.86566646, 0.86910298,
#        0.88107294, 0.86863965, 0.8803007 , 0.88130461, 0.88408473,
#        0.88223134, 0.88744401, 0.89902782, 0.90748401, 0.90698203,
#        0.91624911, 0.92497556, 0.93679104, 0.93818109, 0.93829693,
#        0.93752469, 0.95262226, 0.95656078, 0.95161836, 0.95729443,
#        0.95795084, 0.96918708, 0.97860859, 0.95764193, 0.9643605 ,
#        0.98250851, 0.9855203 , 0.99683385, 1.        , 0.98675587,
#        0.97366617, 0.96679312, 0.94142461, 0.93953256, 0.94586504])

# %%
test_data.shape
# Out:
# (60, 1)

# %%
def get_pred(test_data:list)-> float:
    x_test = np.array(test_data)

    # Reshape the data
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

    # Get the models predicted price values 
    predictions = model.predict(x_test)
    # predictions = scaler.inverse_transform(predictions)
    return predictions

# %%
predictions = []
for i in range(100):
    result = get_pred([data_array])
    predictions.append(scaler.inverse_transform(result))
    data_array = np.append(data_array,result[0])[-60:]
    print(f"Done predicting for {i}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Done predicting for 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Done predicting for 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Done predicting for 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Done predicting for 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Done predicting for 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Done predicting for 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Done predicting for 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Done predicting for 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Done predicting for 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Done predicting for 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Done predicting for 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Done predicting for 11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# Done predicting for 12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Done predicting for 13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Done predicting for 14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Done predicting for 15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Done predicting for 16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Done predicting for 17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Done predicting for 18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Done predicting for 19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Done predicting for 20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Done predicting for 21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Done predicting for 22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Done predicting for 23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Done predicting for 24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Done predicting for 25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Done predicting for 26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Done predicting for 27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Done predicting for 28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Done predicting for 29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Done predicting for 30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Done predicting for 31
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Done predicting for 32
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Done predicting for 33
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Done predicting for 34
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Done predicting for 35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Done predicting for 36
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Done predicting for 37
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Done predicting for 38
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Done predicting for 39
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Done predicting for 40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Done predicting for 41
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Done predicting for 42
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Done predicting for 43
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Done predicting for 44
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Done predicting for 45
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Done predicting for 46
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Done predicting for 47
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Done predicting for 48
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Done predicting for 49
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Done predicting for 50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Done predicting for 51
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Done predicting for 52
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Done predicting for 53
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Done predicting for 54
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Done predicting for 55
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Done predicting for 56
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Done predicting for 57
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Done predicting for 58
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Done predicting for 59
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Done predicting for 60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Done predicting for 61
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Done predicting for 62
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Done predicting for 63
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Done predicting for 64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Done predicting for 65
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Done predicting for 66
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Done predicting for 67
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Done predicting for 68
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Done predicting for 69
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Done predicting for 70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Done predicting for 71
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Done predicting for 72
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Done predicting for 73
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Done predicting for 74
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Done predicting for 75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Done predicting for 76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Done predicting for 77
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Done predicting for 78
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Done predicting for 79
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Done predicting for 80
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Done predicting for 81
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Done predicting for 82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Done predicting for 83
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Done predicting for 84
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Done predicting for 85
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Done predicting for 86
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Done predicting for 87
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Done predicting for 88
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Done predicting for 89
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Done predicting for 90
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Done predicting for 91
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Done predicting for 92
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Done predicting for 93
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Done predicting for 94
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Done predicting for 95
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Done predicting for 96
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Done predicting for 97
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Done predicting for 98
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Done predicting for 99

# %%
predictions = [arr.item() for arr in predictions]
predictions
# Out:
# [221.7320098876953,
#  214.997802734375,
#  208.43316650390625,
#  202.75697326660156,
#  198.01419067382812,
#  193.995361328125,
#  190.43634033203125,
#  187.1160125732422,
#  183.90419006347656,
#  180.76364135742188,
#  177.71859741210938,
#  174.81166076660156,
#  172.07073974609375,
#  169.4954833984375,
#  167.06304931640625,
#  164.74310302734375,
#  162.51158142089844,
#  160.3570556640625,
#  158.27854919433594,
#  156.2796630859375,
#  154.36224365234375,
#  152.52342224121094,
#  150.7563934326172,
#  149.05282592773438,
#  147.40576171875,
#  145.81072998046875,
#  144.2655029296875,
#  142.76898193359375,
#  141.31980895996094,
#  139.91604614257812,
#  138.55490112304688,
#  137.2334442138672,
#  135.94900512695312,
#  134.69949340820312,
#  133.48336791992188,
#  132.29930114746094,
#  131.1461181640625,
#  130.02247619628906,
#  128.927001953125,
#  127.85826110839844,
#  126.81500244140625,
#  125.79605102539062,
#  124.8003921508789,
#  123.82713317871094,
#  122.87541198730469,
#  121.94438934326172,
#  121.0332260131836,
#  120.1411361694336,
#  119.26734924316406,
#  118.41119384765625,
#  117.57198333740234,
#  116.74910736083984,
#  115.94200897216797,
#  115.15013122558594,
#  114.37293243408203,
#  113.6098861694336,
#  112.86054992675781,
#  112.12442779541016,
#  111.40109252929688,
#  110.69013214111328,
#  109.99113464355469,
#  109.30375671386719,
#  108.62757873535156,
#  107.96231079101562,
#  107.30757904052734,
#  106.66309356689453,
#  106.0285415649414,
#  105.40361022949219,
#  104.7880630493164,
#  104.18157196044922,
#  103.58394622802734,
#  102.99490356445312,
#  102.41421508789062,
#  101.84164428710938,
#  101.27696990966797,
#  100.7199935913086,
#  100.1705322265625,
#  99.62833404541016,
#  99.09327697753906,
#  98.56510925292969,
#  98.04371643066406,
#  97.5289077758789,
#  97.02051544189453,
#  96.51839447021484,
#  96.02240753173828,
#  95.5323715209961,
#  95.04815673828125,
#  94.56965637207031,
#  94.09671020507812,
#  93.62920379638672,
#  93.16699981689453,
#  92.70999908447266,
#  92.2580795288086,
#  91.8111343383789,
#  91.36904907226562,
#  90.93169403076172,
#  90.4990234375,
#  90.07089233398438,
#  89.6472396850586,
#  89.22795104980469]

# %%
results = get_pred([test_data[-61:-1,0]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step

# %%
scaler.inverse_transform(results)
# Out:
# array([[221.73201]], dtype=float32)

# %%
c = np.append(data_array,results)

# %%
c[-60:]
# Out:
# array([0.87752029, 0.89198414, 0.90181955, 0.89383547, 0.89526259,
#        0.9062551 , 0.91196351, 0.9095722 , 0.88990132, 0.88916855,
#        0.89240841, 0.90008387, 0.90112526, 0.8873557 , 0.87119476,
#        0.85962368, 0.85615233, 0.86170644, 0.85889085, 0.87725026,
#        0.87620776, 0.86566646, 0.86566646, 0.86910298, 0.88107294,
#        0.86863965, 0.8803007 , 0.88130461, 0.88408473, 0.88223134,
#        0.88744401, 0.89902782, 0.90748401, 0.90698203, 0.91624911,
#        0.92497556, 0.93679104, 0.93818109, 0.93829693, 0.93752469,
#        0.95262226, 0.95656078, 0.95161836, 0.95729443, 0.95795084,
#        0.96918708, 0.97860859, 0.95764193, 0.9643605 , 0.98250851,
#        0.9855203 , 0.99683385, 1.        , 0.98675587, 0.97366617,
#        0.96679312, 0.94142461, 0.93953256, 0.94586504, 0.85602105])

# %%
x_test[-1]
# Out:
# array([0.88326724, 0.87752029, 0.89198414, 0.90181955, 0.89383547,
#        0.89526259, 0.9062551 , 0.91196351, 0.9095722 , 0.88990132,
#        0.88916855, 0.89240841, 0.90008387, 0.90112526, 0.8873557 ,
#        0.87119476, 0.85962368, 0.85615233, 0.86170644, 0.85889085,
#        0.87725026, 0.87620776, 0.86566646, 0.86566646, 0.86910298,
#        0.88107294, 0.86863965, 0.8803007 , 0.88130461, 0.88408473,
#        0.88223134, 0.88744401, 0.89902782, 0.90748401, 0.90698203,
#        0.91624911, 0.92497556, 0.93679104, 0.93818109, 0.93829693,
#        0.93752469, 0.95262226, 0.95656078, 0.95161836, 0.95729443,
#        0.95795084, 0.96918708, 0.97860859, 0.95764193, 0.9643605 ,
#        0.98250851, 0.9855203 , 0.99683385, 1.        , 0.98675587,
#        0.97366617, 0.96679312, 0.94142461, 0.93953256, 0.94586504])
